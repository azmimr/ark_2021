# %%
import os
import math
import pandas as pd
import numpy as np
import pprint
from collections import defaultdict

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt

# %%
random_state = 20

# %%
train_val_df = pd.read_csv("../data/train.csv")
test_df = pd.read_csv("../data/test.csv")

# %%
train_val_df = train_val_df.sample(frac=1)

train_prop = 0.7
num_train_val = train_val_df.shape[0]
num_train = int(train_prop*num_train_val)

train_df = train_val_df.iloc[:num_train]
val_df = train_val_df.iloc[num_train:]

# %%
train_df["dataset"] = "train"
val_df["dataset"] = "val"
test_df["dataset"] = "test"
# Out:
# /Users/kenneth/Documents/experiment_venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/kenneth/Documents/experiment_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
combined_df = pd.concat([train_df, val_df, test_df])
combined_df
# Out:
#           month             town flat_type block                street_name  \
# 342754  2015-08      bukit batok    4 room   108  Bukit Batok West Avenue 6
# 203627  2005-03    choa chu kang    4 room   218      choa chu kang central
# 333899  2013-03         tampines    4-room   280         Tampines Street 22
# 382154  2000-11           yishun    4 room   855           yishun ring road
# 394403  2007-12          punggol    4 room  171A            edgedale plains
# ...         ...              ...       ...   ...                        ...
# 107929  2008-04          hougang    5 room  981D          buangkok crescent
# 107930  2006-01  kallang/whampoa    4 room    13       upper boon keng road
# 107931  2000-01  kallang/whampoa    3 room     1                 beach road
# 107932  2009-07      jurong west    4 room   919      jurong west street 91
# 107933  2010-05         sengkang    4-room  201A          Compassvale Drive
#
#        storey_range  floor_area_sqm flat_model   eco_category  \
# 342754     07 to 09           107.0    model a  uncategorized
# 203627     04 to 06           106.0    model a  uncategorized
# 333899     07 to 09           104.0    model a  uncategorized
# 382154     04 to 06           109.0    model a  uncategorized
# 394403     07 to 09            85.0    model a  uncategorized
# ...             ...             ...        ...            ...
# 107929     10 to 12           110.0   improved  uncategorized
# 107930     13 to 15           102.0    model a  uncategorized
# 107931     07 to 09            68.0   improved  uncategorized
# 107932     10 to 12           104.0    model a  uncategorized
# 107933     04 to 06            90.0    model a  uncategorized
#
#         lease_commence_date  latitude   longitude  elevation  \
# 342754                 1985  1.347444  103.746502        0.0
# 203627                 1990  1.382838  103.745842        0.0
# 333899                 1984  1.347535  103.951703        0.0
# 382154                 1988  1.417031  103.836824        0.0
# 394403                 2004  1.394631  103.912294        0.0
# ...                     ...       ...         ...        ...
# 107929                 2003  1.380452  103.879333        0.0
# 107930                 1999  1.314481  103.870458        0.0
# 107931                 1979  1.294924  103.854315        0.0
# 107932                 1988  1.339927  103.687354        0.0
# 107933                 2001  1.389001  103.892763        0.0
#
#                       subzone  planning_area             region  resale_price  \
# 342754    bukit batok central    bukit batok        west region      423000.0
# 203627  choa chu kang central  choa chu kang        west region      209250.0
# 333899          tampines east       tampines        east region      435600.0
# 382154           yishun south         yishun       north region      225900.0
# 394403          punggol field        punggol  north-east region      270000.0
# ...                       ...            ...                ...           ...
# 107929              trafalgar        hougang  north-east region           NaN
# 107930              boon keng        kallang     central region           NaN
# 107931              city hall  downtown core     central region           NaN
# 107932                 yunnan    jurong west        west region           NaN
# 107933   sengkang town centre       sengkang  north-east region           NaN
#
#        dataset
# 342754   train
# 203627   train
# 333899   train
# 382154   train
# 394403   train
# ...        ...
# 107929    test
# 107930    test
# 107931    test
# 107932    test
# 107933    test
#
# [539666 rows x 18 columns]

# %% [markdown]
# ##### Preprocessing

# %% [markdown]
# check nan

# %%
combined_df.isnull().sum().sort_index()/len(combined_df)
# Out:
# block                  0.000000
# dataset                0.000000
# eco_category           0.000000
# elevation              0.000000
# flat_model             0.000000
# flat_type              0.000000
# floor_area_sqm         0.000000
# latitude               0.000000
# lease_commence_date    0.000000
# longitude              0.000000
# month                  0.000000
# planning_area          0.000000
# region                 0.000000
# resale_price           0.200001
# storey_range           0.000000
# street_name            0.000000
# subzone                0.000000
# town                   0.000000
# dtype: float64

# %% [markdown]
# Select relevant columns

# %%
def generate_new_features(features_df):
    # new features
    features_df_copy = features_df.copy()
    features_df_copy["month"] = features_df_copy["month"].astype('datetime64[ns]')
    features_df_copy["year"] = features_df_copy["month"].dt.year
    features_df_copy["flat_type"] = features_df_copy["flat_type"].apply(lambda x: x.replace("-", " "))
    features_df_copy["min_storey"] = features_df_copy["storey_range"].apply(lambda x: int(x.split("to")[0].strip().replace("0", ""))).astype(int)
    features_df_copy["max_storey"] = features_df_copy["storey_range"].apply(lambda x: int(x.split("to")[1].strip().replace("0", ""))).astype(int)
    
    # remove unwanted columns
    features_df_copy = features_df_copy.drop(["month", "storey_range"], axis=1)

    return features_df_copy

# %%
def cat_transform(combined_df):
    combined_df_copy = combined_df.copy()
    mapping = {
        "flat_type": {
            "1 room": 1, "2 room": 2,
            "3 room": 3, "4 room": 4,
            "5 room": 5, "executive": 6,
            "multi generation": 7
        }
    }
    combined_df_copy = combined_df_copy.replace(mapping)
    
    combined_df_copy = pd.get_dummies(combined_df_copy, columns=["planning_area"])

    return combined_df_copy

# %%
def transform(combined_df):
    
    combined_df_new_f = generate_new_features(combined_df)
    
    transformed_combined_df = cat_transform(combined_df_new_f)
    
    return transformed_combined_df

# %%
transformed_combined_df = transform(combined_df)
transformed_combined_df
# Out:
#                    town  flat_type block                street_name  \
# 342754      bukit batok          4   108  Bukit Batok West Avenue 6
# 203627    choa chu kang          4   218      choa chu kang central
# 333899         tampines          4   280         Tampines Street 22
# 382154           yishun          4   855           yishun ring road
# 394403          punggol          4  171A            edgedale plains
# ...                 ...        ...   ...                        ...
# 107929          hougang          5  981D          buangkok crescent
# 107930  kallang/whampoa          4    13       upper boon keng road
# 107931  kallang/whampoa          3     1                 beach road
# 107932      jurong west          4   919      jurong west street 91
# 107933         sengkang          4  201A          Compassvale Drive
#
#         floor_area_sqm flat_model   eco_category  lease_commence_date  \
# 342754           107.0    model a  uncategorized                 1985
# 203627           106.0    model a  uncategorized                 1990
# 333899           104.0    model a  uncategorized                 1984
# 382154           109.0    model a  uncategorized                 1988
# 394403            85.0    model a  uncategorized                 2004
# ...                ...        ...            ...                  ...
# 107929           110.0   improved  uncategorized                 2003
# 107930           102.0    model a  uncategorized                 1999
# 107931            68.0   improved  uncategorized                 1979
# 107932           104.0    model a  uncategorized                 1988
# 107933            90.0    model a  uncategorized                 2001
#
#         latitude   longitude  ...  planning_area_rochor  \
# 342754  1.347444  103.746502  ...                     0
# 203627  1.382838  103.745842  ...                     0
# 333899  1.347535  103.951703  ...                     0
# 382154  1.417031  103.836824  ...                     0
# 394403  1.394631  103.912294  ...                     0
# ...          ...         ...  ...                   ...
# 107929  1.380452  103.879333  ...                     0
# 107930  1.314481  103.870458  ...                     0
# 107931  1.294924  103.854315  ...                     0
# 107932  1.339927  103.687354  ...                     0
# 107933  1.389001  103.892763  ...                     0
#
#        planning_area_sembawang planning_area_sengkang  \
# 342754                       0                      0
# 203627                       0                      0
# 333899                       0                      0
# 382154                       0                      0
# 394403                       0                      0
# ...                        ...                    ...
# 107929                       0                      0
# 107930                       0                      0
# 107931                       0                      0
# 107932                       0                      0
# 107933                       0                      1
#
#         planning_area_serangoon planning_area_sungei kadut  \
# 342754                        0                          0
# 203627                        0                          0
# 333899                        0                          0
# 382154                        0                          0
# 394403                        0                          0
# ...                         ...                        ...
# 107929                        0                          0
# 107930                        0                          0
# 107931                        0                          0
# 107932                        0                          0
# 107933                        0                          0
#
#         planning_area_tampines  planning_area_tanglin  \
# 342754                       0                      0
# 203627                       0                      0
# 333899                       1                      0
# 382154                       0                      0
# 394403                       0                      0
# ...                        ...                    ...
# 107929                       0                      0
# 107930                       0                      0
# 107931                       0                      0
# 107932                       0                      0
# 107933                       0                      0
#
#         planning_area_toa payoh  planning_area_woodlands  planning_area_yishun
# 342754                        0                        0                     0
# 203627                        0                        0                     0
# 333899                        0                        0                     0
# 382154                        0                        0                     1
# 394403                        0                        0                     0
# ...                         ...                      ...                   ...
# 107929                        0                        0                     0
# 107930                        0                        0                     0
# 107931                        0                        0                     0
# 107932                        0                        0                     0
# 107933                        0                        0                     0
#
# [539666 rows x 50 columns]

# %%
transformed_combined_df_subset = transformed_combined_df.drop(["town", "flat_type", "block", "street_name", "flat_model", "eco_category", "latitude", "longitude", "elevation", "subzone", "region"], axis=1)
transformed_combined_df_subset
# Out:
#         floor_area_sqm  lease_commence_date  resale_price dataset  year  \
# 342754           107.0                 1985      423000.0   train  2015
# 203627           106.0                 1990      209250.0   train  2005
# 333899           104.0                 1984      435600.0   train  2013
# 382154           109.0                 1988      225900.0   train  2000
# 394403            85.0                 2004      270000.0   train  2007
# ...                ...                  ...           ...     ...   ...
# 107929           110.0                 2003           NaN    test  2008
# 107930           102.0                 1999           NaN    test  2006
# 107931            68.0                 1979           NaN    test  2000
# 107932           104.0                 1988           NaN    test  2009
# 107933            90.0                 2001           NaN    test  2010
#
#         min_storey  max_storey  planning_area_ang mo kio  planning_area_bedok  \
# 342754           7           9                         0                    0
# 203627           4           6                         0                    0
# 333899           7           9                         0                    0
# 382154           4           6                         0                    0
# 394403           7           9                         0                    0
# ...            ...         ...                       ...                  ...
# 107929           1          12                         0                    0
# 107930          13          15                         0                    0
# 107931           7           9                         0                    0
# 107932           1          12                         0                    0
# 107933           4           6                         0                    0
#
#         planning_area_bishan  ...  planning_area_rochor  \
# 342754                     0  ...                     0
# 203627                     0  ...                     0
# 333899                     0  ...                     0
# 382154                     0  ...                     0
# 394403                     0  ...                     0
# ...                      ...  ...                   ...
# 107929                     0  ...                     0
# 107930                     0  ...                     0
# 107931                     0  ...                     0
# 107932                     0  ...                     0
# 107933                     0  ...                     0
#
#         planning_area_sembawang  planning_area_sengkang  \
# 342754                        0                       0
# 203627                        0                       0
# 333899                        0                       0
# 382154                        0                       0
# 394403                        0                       0
# ...                         ...                     ...
# 107929                        0                       0
# 107930                        0                       0
# 107931                        0                       0
# 107932                        0                       0
# 107933                        0                       1
#
#         planning_area_serangoon  planning_area_sungei kadut  \
# 342754                        0                           0
# 203627                        0                           0
# 333899                        0                           0
# 382154                        0                           0
# 394403                        0                           0
# ...                         ...                         ...
# 107929                        0                           0
# 107930                        0                           0
# 107931                        0                           0
# 107932                        0                           0
# 107933                        0                           0
#
#         planning_area_tampines  planning_area_tanglin  \
# 342754                       0                      0
# 203627                       0                      0
# 333899                       1                      0
# 382154                       0                      0
# 394403                       0                      0
# ...                        ...                    ...
# 107929                       0                      0
# 107930                       0                      0
# 107931                       0                      0
# 107932                       0                      0
# 107933                       0                      0
#
#         planning_area_toa payoh  planning_area_woodlands  planning_area_yishun
# 342754                        0                        0                     0
# 203627                        0                        0                     0
# 333899                        0                        0                     0
# 382154                        0                        0                     1
# 394403                        0                        0                     0
# ...                         ...                      ...                   ...
# 107929                        0                        0                     0
# 107930                        0                        0                     0
# 107931                        0                        0                     0
# 107932                        0                        0                     0
# 107933                        0                        0                     0
#
# [539666 rows x 39 columns]

# %% [markdown]
# After transforming, separate out the dataset again

# %%
train_df_processed = transformed_combined_df_subset.query("dataset == 'train'")
val_df_processed = transformed_combined_df_subset.query("dataset == 'val'")
test_df_processed = transformed_combined_df_subset.query("dataset == 'test'")

# %%
def get_features_labels(df):
    features_df = df.drop(["resale_price", "dataset"], axis=1)
    labels = df["resale_price"].ravel()
    
    return features_df, labels

# %%
train_features_df, train_labels = get_features_labels(train_df_processed)
val_features_df, val_labels = get_features_labels(val_df_processed)
test_features_df, test_labels = get_features_labels(test_df_processed)

# %%
val_features_df
# Out:
#         floor_area_sqm  lease_commence_date  year  min_storey  max_storey  \
# 16378            120.0                 1999  2016           1           3
# 79018            150.0                 1985  2019           1          12
# 233140            84.0                 1985  2002           1          12
# 180798            57.0                 1971  2019           7           9
# 200230            78.0                 1984  2008           1           3
# ...                ...                  ...   ...         ...         ...
# 371702            74.0                 1987  2017           4           6
# 343418           143.0                 1998  2020           1          12
# 367508            67.0                 1977  2008           4           6
# 428044            68.0                 1984  2010           4           6
# 32819             64.0                 1988  2013           1          12
#
#         planning_area_ang mo kio  planning_area_bedok  planning_area_bishan  \
# 16378                          0                    0                     0
# 79018                          0                    0                     0
# 233140                         0                    1                     0
# 180798                         0                    0                     0
# 200230                         0                    0                     0
# ...                          ...                  ...                   ...
# 371702                         0                    0                     0
# 343418                         0                    0                     0
# 367508                         0                    1                     0
# 428044                         0                    0                     0
# 32819                          0                    0                     0
#
#         planning_area_bukit batok  planning_area_bukit merah  ...  \
# 16378                           0                          0  ...
# 79018                           0                          0  ...
# 233140                          0                          0  ...
# 180798                          0                          0  ...
# 200230                          0                          0  ...
# ...                           ...                        ...  ...
# 371702                          0                          0  ...
# 343418                          0                          0  ...
# 367508                          0                          0  ...
# 428044                          0                          0  ...
# 32819                           1                          0  ...
#
#         planning_area_rochor  planning_area_sembawang  planning_area_sengkang  \
# 16378                      0                        1                       0
# 79018                      0                        0                       0
# 233140                     0                        0                       0
# 180798                     0                        0                       0
# 200230                     0                        0                       0
# ...                      ...                      ...                     ...
# 371702                     0                        0                       0
# 343418                     0                        0                       0
# 367508                     0                        0                       0
# 428044                     0                        0                       0
# 32819                      0                        0                       0
#
#         planning_area_serangoon  planning_area_sungei kadut  \
# 16378                         0                           0
# 79018                         0                           0
# 233140                        0                           0
# 180798                        0                           0
# 200230                        0                           0
# ...                         ...                         ...
# 371702                        0                           0
# 343418                        0                           0
# 367508                        0                           0
# 428044                        0                           0
# 32819                         0                           0
#
#         planning_area_tampines  planning_area_tanglin  \
# 16378                        0                      0
# 79018                        0                      0
# 233140                       0                      0
# 180798                       0                      0
# 200230                       1                      0
# ...                        ...                    ...
# 371702                       0                      0
# 343418                       0                      0
# 367508                       0                      0
# 428044                       0                      0
# 32819                        0                      0
#
#         planning_area_toa payoh  planning_area_woodlands  planning_area_yishun
# 16378                         0                        0                     0
# 79018                         0                        0                     0
# 233140                        0                        0                     0
# 180798                        0                        0                     0
# 200230                        0                        0                     0
# ...                         ...                      ...                   ...
# 371702                        0                        0                     1
# 343418                        0                        0                     0
# 367508                        0                        0                     0
# 428044                        0                        0                     1
# 32819                         0                        0                     0
#
# [129520 rows x 37 columns]

# %% [markdown]
# #### Metrics

# %%
def root_mean_squared_error(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    
    return rmse

def calculate_rmse(features_df, labels):
    preds = rf.predict(features_df)
    rmse = root_mean_squared_error(labels, preds)

    return rmse

# %% [markdown]
# #### RandomSearch

# %%
def run_random_search_cv(model, grid, train_features_df, train_labels, test_features_df, random_state=random_state):

    # Use the random grid to search for best hyperparameters
    # First create the base model to tune
    m = model(random_state=random_state)

    # Random search of parameters, using 3 fold cross validation, 
    # search across 100 different combinations, and use all available cores
    random_search = RandomizedSearchCV(
        estimator=m, param_distributions=grid, n_iter=1, scoring=make_scorer(root_mean_squared_error),
        cv=3, verbose=2, random_state=random_state, n_jobs = -1, error_score="raise"
    )

    # Fit the random search model
    random_search.fit(train_features_df, train_labels)
    test_labels = random_search.predict(test_features_df)

    return random_search, test_labels

# %% [markdown]
# #### GridSearch

# %%
def run_grid_search_cv(model, grid, train_features_df, train_labels, test_features_df, random_state=random_state):
    
    # Create a based model
    m = model(random_state=random_state)
    # Instantiate the grid search model
    grid_search = GridSearchCV(
        estimator=m, param_grid=grid, scoring=make_scorer(root_mean_squared_error),
        cv=3, n_jobs=-1, verbose=2, error_score="raise"
    )

    # Fit the grid search to the data
    grid_search.fit(train_features_df, train_labels)
    test_labels = grid_search.predict(test_features_df)
    
    return grid_search, test_labels

# %% [markdown]
# #### Run GridSearch or RandomSearch on multiple models

# %%
def run_search_on_multiple_models(models, model_names, grids, train_features_df, train_labels, test_features_df, search_type="random_search"):
    search_results = {}

    for model_name in model_names:
        grid = grids[model_name]
        model = models[model_name]
        
        if search_type == "random_search":
            search_result = run_random_search_cv(model, grid, train_features_df, train_labels, test_features_df)
        elif search_type == "grid_search":
            search_result = run_grid_search_cv(model, grid, train_features_df, train_labels, test_features_df)
        search_results[model_name] = search_result
    
    return search_results

# %%
models = {
    "RandomForestRegressor": RandomForestRegressor,
    "GradientBoostingRegressor": GradientBoostingRegressor
}

model_names = ["RandomForestRegressor", "GradientBoostingRegressor"]

# %% [markdown]
# RandomSearch

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start=10, stop=500, num=20)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num=11)]

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 20, 30, 40]

# Minimum number of samples required at each leaf node
min_samples_leaf = [2, 5, 10, 20, 30, 40]

# Create the random grid
random_grid = {
    'n_estimators': n_estimators,
    'max_features': max_features,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf
}


random_grids = {
    "RandomForestRegressor": random_grid,
    "GradientBoostingRegressor": random_grid
}

# %%
random_search_results = run_search_on_multiple_models(models, model_names, random_grids, train_features_df, train_labels, test_features_df, search_type="random_search")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits

# %%
random_search_feature_impt_results = defaultdict()
for model_name in model_names:
    print(model_name)
    print("Best Params")
    print(random_search_results[model_name][0].best_params_)
    print("Best Score")
    print(random_search_results[model_name][0].best_score_)
    print("Feature importance Params")
    raw_feature_importances = random_search_results[model_name][0].best_estimator_.feature_importances_
    random_search_feature_impt_results[model_name] = raw_feature_importances
    feature_importances = sorted(list(zip(train_features_df.columns, raw_feature_importances)), key=lambda x: x[1], reverse=True)
    print(feature_importances)
    print("Best Params Predictions")
    print(random_search_results[model_name][1])
    print("\n")
# Out:
# RandomForestRegressor
# Best Params
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-402a3cdf3f70> in <module>
#       3     print(model_name)
#       4     print("Best Params")
# ----> 5     print(random_search_results[model_name][0].best_params_)
#       6     print("Best Score")
#       7     print(random_search_results[model_name][0].best_score_)
#
# NameError: name 'random_search_results' is not defined

# %% [markdown]
# GridSearch

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start=10, stop=100, num=1)]

# Number of features to consider at every split
max_features = ['auto']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num=1)]
# max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1]

# Create the random grid
grid_search_grid = {
    'n_estimators': n_estimators,
    'max_features': max_features,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf
}


grid_search_grids = {
    "RandomForestRegressor": grid_search_grid,
    "GradientBoostingRegressor": grid_search_grid
}

# %%
grid_search_results = run_search_on_multiple_models(models, model_names, grid_search_grids, train_features_df, train_labels, test_features_df, search_type="grid_search")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits

# %%
grid_search_feature_impt_results = defaultdict()
for model_name in model_names:
    print(model_name)
    print("Best Params")
    print(grid_search_results[model_name][0].best_params_)
    print("Feature importance Params")
    raw_feature_importances = grid_search_results[model_name][0].best_estimator_.feature_importances_
    grid_search_feature_impt_results[model_name] = raw_feature_importances
    feature_importances = sorted(list(zip(train_features_df.columns, raw_feature_importances)), key=lambda x: x[1], reverse=True)
    print(feature_importances)
    print("Best Params Predictions")
    print(grid_search_results[model_name][1])
    print("\n")
# Out:
# RandomForestRegressor
# Best Params
# {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# Feature importance Params
# [('year', 0.46392550473706995), ('floor_area_sqm', 0.39598466195615456), ('min_storey', 0.035974867631929225), ('lease_commence_date', 0.026928854275904905), ('planning_area_bukit merah', 0.02051381347507169), ('planning_area_queenstown', 0.012886832273843385), ('planning_area_bishan', 0.010693610043674123), ('planning_area_woodlands', 0.007584543318464171), ('planning_area_outram', 0.005289704727274821), ('planning_area_toa payoh', 0.0026532573389134377), ('planning_area_jurong west', 0.002451842815507502), ('planning_area_sengkang', 0.0018870143256441256), ('planning_area_tampines', 0.001732568210874089), ('planning_area_kallang', 0.0014981747128727397), ('planning_area_marine parade', 0.0014510103769988906), ('planning_area_choa chu kang', 0.0013783204797963335), ('planning_area_yishun', 0.0011652883133945239), ('planning_area_ang mo kio', 0.0011189197823943016), ('planning_area_geylang', 0.001010627062301586), ('planning_area_bukit panjang', 0.0009699312946343226), ('max_storey', 0.0007501110206658421), ('planning_area_bukit timah', 0.0005557869392563898), ('planning_area_bukit batok', 0.000351195351600348), ('planning_area_jurong east', 0.0003330814889257514), ('planning_area_clementi', 0.00022599701349697025), ('planning_area_sembawang', 0.00019070082694959016), ('planning_area_rochor', 0.00012220774239119782), ('planning_area_serangoon', 0.00011866664491318442), ('planning_area_downtown core', 0.00010270383021948825), ('planning_area_novena', 0.00010174041680107069), ('planning_area_bedok', 4.285953976989772e-05), ('planning_area_hougang', 5.602032291598448e-06), ('planning_area_changi', 0.0), ('planning_area_pasir ris', 0.0), ('planning_area_punggol', 0.0), ('planning_area_sungei kadut', 0.0), ('planning_area_tanglin', 0.0)]
# Best Params Predictions
# [208188.4320699  311374.47779932 134361.70119277 ... 134361.70119277
#  297356.73642188 348830.27024033]
#
#
# GradientBoostingRegressor
# Best Params
# {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# Feature importance Params
# [('year', 0.4555916089252922), ('floor_area_sqm', 0.38718547252845953), ('min_storey', 0.03641291861530582), ('lease_commence_date', 0.032324813230429), ('planning_area_bukit merah', 0.019099334801337534), ('planning_area_queenstown', 0.011724875215447926), ('planning_area_bishan', 0.009539282751856247), ('planning_area_woodlands', 0.00886542525915763), ('planning_area_outram', 0.005016584751319895), ('planning_area_jurong west', 0.004711610221275914), ('planning_area_toa payoh', 0.004698605772209684), ('planning_area_choa chu kang', 0.003013653307637989), ('planning_area_sengkang', 0.0028920786383193403), ('planning_area_kallang', 0.002649939126563719), ('planning_area_marine parade', 0.0022099767266446644), ('planning_area_bukit panjang', 0.0018998129045950825), ('planning_area_yishun', 0.0018667218233129946), ('max_storey', 0.0016199054517943067), ('planning_area_tampines', 0.0013268739795946032), ('planning_area_clementi', 0.0010551967678969927), ('planning_area_geylang', 0.0010260859617513538), ('planning_area_bukit timah', 0.0008668556971679231), ('planning_area_ang mo kio', 0.0008661271287544365), ('planning_area_sembawang', 0.0007580723024757767), ('planning_area_jurong east', 0.000664965376332955), ('planning_area_bukit batok', 0.0005635938796431639), ('planning_area_serangoon', 0.0004678403063965849), ('planning_area_punggol', 0.0003876134148590014), ('planning_area_downtown core', 0.0002150868317862039), ('planning_area_rochor', 0.00018035949366237945), ('planning_area_novena', 0.00015059069508242183), ('planning_area_bedok', 8.272856622547264e-05), ('planning_area_hougang', 3.5844314343526785e-05), ('planning_area_tanglin', 1.9936887767620674e-05), ('planning_area_changi', 9.570179123804815e-06), ('planning_area_pasir ris', 3.81661763612156e-08), ('planning_area_sungei kadut', 0.0)]
# Best Params Predictions
# [238052.32905116 306242.82225452 189670.26710738 ... 195248.09235426
#  292923.41503568 333136.42890575]

# %% [markdown]
# #### Feature Selection

# %% [markdown]
# There is a sklearn webpage which highlighted that the impurity-based feature importance of RandomForestClassifier (I guess it applies to regressor to) can inflate the importance of the features with high cardinality. Furthermore, impurity-based importances are computed on training set statistics and therefore do not reflect the ability of feature to be useful to make predictions that generalize to the test set (when the model has enough capacity). The webpage suggests that Permutation Importances can be used as an alternative that can mitigate those limitations.

# %%
def plot_impt(impt_arr, labels, model_name, impt_type):
    fig, ax = plt.subplots()
    ax.boxplot(impt_arr,
               vert=False, labels=labels)
    ax.set_title(f"{model_name}'s' {impt_type}")
    fig.tight_layout()
    plt.show()

# %% [markdown]
# Permutation Importance

# %%
def run_perm_impt(model, X_val, y_val, n_repeats=10, random_state=random_state, n_jobs=2):
    
    result = permutation_importance(
        model, X_val, y_val, n_repeats=n_repeats,
        random_state=random_state, n_jobs=n_jobs
    )
    sorted_idx = result.importances_mean.argsort()
    perm_impt_arr = result.importances[sorted_idx].T
    labels = X_val.columns[sorted_idx]
    return perm_impt_arr, labels

# %%
perm_impt_results = defaultdict()
for model_name in model_names:
    best_estimator = grid_search_results[model_name][0].best_estimator_
    perm_impt_arr, labels = run_perm_impt(best_estimator, val_features_df, val_labels)
    perm_impt_results[model_name] = (perm_impt_arr, labels)

# %%
for model_name in model_names:
    model_perm_impt_results = perm_impt_results[model_name]
    plot_impt(model_perm_impt_results[0], model_perm_impt_results[1], model_name, "permutation importances")

# %% [markdown]
# Feature importance

# %%
for model_name in model_names:
    model_feature_impt = grid_search_feature_impt_results[model_name]
    sorted_idx = model_feature_impt.argsort()
    model_feature_impt_arr = model_feature_impt[sorted_idx].T.reshape(1,-1)
    labels = train_features_df.columns[sorted_idx]
    plot_impt(model_feature_impt_arr, labels, model_name, "feature importance")

# %% [markdown]
# Seems to have roughly the same feature ordering as random forest's inbuild feature importance

# %% [markdown]
# #### Ensemble predictions

# %%
predictions = [r[1] for r in random_search_results.values()]
average_predictions = np.mean(predictions, axis=0)
average_predictions

# %%
submission = pd.DataFrame()
submission["Id"] = range(average_predictions.shape[0])
submission["Predicted"] = average_predictions

# %%
submission.to_csv("submission.csv", index=False)
